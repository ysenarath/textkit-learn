# %% [markdown]
# # This notebook contains code for improving the definitions and other metadata from the wiktionary dataset using a language model.
#
# - Note: This notebook is not complete.

# %%
from pathlib import Path

cache_dir = Path("../cache")

# %%
import pandas as pd

df = pd.read_parquet(cache_dir / "wiktionary_definitions.parquet")

# %%
df.columns

# %%
def get_better_definition(row):
    print(f"Current definition: {row['definition']}")
    print(f"Word: {row['words']}")
    raise NotImplementedError(
        "Definition improvement logic not implemented yet."
    )

# %%
df["definition_v2"] = df.apply(get_better_definition, axis=1)

df.head()
